# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhiyadurai/Data-Analytics/blob/main/pandas11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
def times2(x):
    return 2*x

# %%
times2(2)
# Out:
# 4

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col1'].apply(times2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col1, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df=pd.read_csv( r"/content/Student_Performance_Details.csv" )

# %%
df
# Out:
#           Name   Reg_No  Maths  Science  English  History  Computer  \
# 0         arun  REG1046     94       84      100       86        91
# 1       aravid  REG1017     66       71       74       97        91
# 2        arush  REG1047     73       90       89       75        63
# 3      aswathi  REG1010     66       92       80       79        70
# 4      chandru  REG1002     76       85       99       51        74
# 5      deepika  REG1037     95       92       63       36        99
# 6      dhanush  REG1045     73       60       93       59        93
# 7       dinesh  REG1019     87       64       42       98        85
# 8         dina  REG1016     76       66       99       38        94
# 9       dharun  REG1039     70       82       85       48        80
# 10      dhiran  REG1008     86       66       66       80        64
# 11       ezhil  REG1042     89       62       72       50        85
# 12      faizil  REG1036     59       84       91       81        37
# ...

# %%
df.head(10)
# Out:
#       Name   Reg_No  Maths  Science  English  History  Computer  Total_Marks  \
# 0     arun  REG1046     94       84      100       86        91          455
# 1   aravid  REG1017     66       71       74       97        91          399
# 2    arush  REG1047     73       90       89       75        63          390
# 3  aswathi  REG1010     66       92       80       79        70          387
# 4  chandru  REG1002     76       85       99       51        74          385
# 5  deepika  REG1037     95       92       63       36        99          385
# 6  dhanush  REG1045     73       60       93       59        93          378
# 7   dinesh  REG1019     87       64       42       98        85          376
# 8     dina  REG1016     76       66       99       38        94          373
# 9   dharun  REG1039     70       82       85       48        80          365
#
#   Result  Rank
# 0   Pass     1
# 1   Pass     2
# 2   Pass     3
# 3   Pass     4
# 4   Pass     5
# 5   Pass     5
# ...

# %%
df.tail(5)
# Out:
#          Name   Reg_No  Maths  Science  English  History  Computer  \
# 45      thiru  REG1021     42       80       45       40        67
# 46     thanya  REG1031     43       47       60       81        42
# 47   thioriga  REG1038     53       50       45       63        46
# 48  rakshitha  REG1030     80       35       35       63        41
# 49      rafal  REG1004     40       55       50       55        52
#
#     Total_Marks Result  Rank
# 45          274   Pass    46
# 46          273   fail    47
# 47          257   fail    48
# 48          254   Pass    49
# 49          252   fail    50

# %%
df.columns
# Out:
# Index(['Name', 'Reg_No', 'Maths', 'Science', 'English', 'History', 'Computer',
#        'Total_Marks', 'Result', 'Rank'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         50 non-null     object
#  1   Reg_No       50 non-null     object
#  2   Maths        50 non-null     int64
#  3   Science      50 non-null     int64
#  4   English      50 non-null     int64
#  5   History      50 non-null     int64
#  6   Computer     50 non-null     int64
#  7   Total_Marks  50 non-null     int64
#  8   Result       50 non-null     object
#  9   Rank         50 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 4.0+ KB

# %%
df.nunique()
# Out:
# Name           49
# Reg_No         50
# Maths          36
# Science        35
# English        37
# History        40
# Computer       31
# Total_Marks    42
# Result          2
# Rank           42
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.plot(df["Maths"],df["Science"])
plt.show()
