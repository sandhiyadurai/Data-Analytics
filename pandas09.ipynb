# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhiyadurai/Data-Analytics/blob/main/pandas09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/dataset.csv")
df
# Out:
#     sino       name  age      city adult\child\ old gender headache cold  \
# 0      1       arun    2       vpm            adult      m      yes   no
# 1      2     aravid    3     karur            child      m      yes  yes
# 2      3       agni    2       trk              old      m       no  yes
# 3      4       banu    3       tvm            adult      f       no  yes
# 4      5    barathi    2       vpm              old      m      yes  yes
# 5      6    chandru    3       trk            child      m      yes  yes
# 6      7     charan    2       tvm            child      m       no  yes
# 7      8    deepika   32       vpm            child      f      yes   no
# 8      9      ezhil    3     karur            child      m       no   no
# 9     10     faizil    2    gingee            adult      m      yes   no
# 10    11     ganesh    4       mkn            adult      m       no   no
# 11    12   gayathri    5       vpm              old      f      yes   no
# ...

# %%
import numpy as np

# %%
d = {
    'A': [1,2, 9,4],
    'B':[5, 7, 7,4],
    'C':[1,2,3,4]
}
df = pd.DataFrame(d)
df
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  7  2
# 2  9  7  3
# 3  4  4  4

# %%
...
