# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhiyadurai/Data-Analytics/blob/main/pandas_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d={
    "A":["name","age","city"],
    "B":["bob",33,"chennai"],
    "C":["ram",32,"india"],
    "d":["tom",31,np.nan]
}
df=pd.DataFrame(d)
df
# Out:
#       A        B      C    d
# 0  name      bob    ram  tom
# 1   age       33     32   31
# 2  city  chennai  india  NaN

# %% [markdown]
# DROP

# %%
df.dropna()
# Out:
#       A    B    C    d
# 0  name  bob  ram  tom
# 1   age   33   32   31

# %%
df.dropna(axis = 0)
# Out:
#       A    B    C    d
# 0  name  bob  ram  tom
# 1   age   33   32   31

# %%
df.dropna(axis = 1)
# Out:
#       A        B      C
# 0  name      bob    ram
# 1   age       33     32
# 2  city  chennai  india

# %% [markdown]
# filling value

# %%
df
# Out:
#       A        B      C    d
# 0  name      bob    ram  tom
# 1   age       33     32   31
# 2  city  chennai  india  NaN

# %%
df.fillna(value = 'Filling Value')
# Out:
#       A        B      C              d
# 0  name      bob    ram            tom
# 1   age       33     32             31
# 2  city  chennai  india  Filling Value

# %%
d = {
    'A': [1,2, np.nan,4],
    'B':[5, np.nan, np.nan,4],
    'C':[1,2,3,4]
}

# %%
df=pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.fillna(value = 'Filling Value')
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
a = df['A'].fillna(value = df['A'].mean())
df
a
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# Name: A, dtype: float64

# %% [markdown]
# GROUP BY

# %%
data = {
    'Company':['FB','FB','IBM'],
    'Person': ['Van','Rakib','Ovi'],
    'Sales': [224, 243, 350]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0      FB    Van    224
# 1      FB  Rakib    243
# 2     IBM    Ovi    350

# %%
Comp = df.groupby('Company')

# %%
# Out:
# Sales    272.333333
# dtype: float64

# %%
# Out:
#     a1  a2   a3
# 0  111   1  abc
# 1  555   2  def
# 2  666   3  ghi
# 3  444   4  xyz

# %%
df['a1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['a2'].nunique()
# Out:
# 4

# %%
df['a1'].value_counts()
# Out:
# a1
# 111    1
# 555    1
# 666    1
# 444    1
# Name: count, dtype: int64

# %% [markdown]
# joining

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}
right = {
    'C':['C0','C1','C2'],
    'D':['D0','D1','D2']
}

# %%
left = pd.DataFrame(left, index = ['k0','k1','k2'])
right = pd.DataFrame(right, index = ['k0','k2','k3'])

# %%
left
# Out:
#       A    B
# k0  NaN  NaN
# k1  NaN  NaN
# k2  NaN  NaN

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C1  D1
# k3  C2  D2
